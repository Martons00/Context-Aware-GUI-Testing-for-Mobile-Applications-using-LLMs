# %%
import os
import json



def calcola_percentuale_corretto(cartella,apps=["note", "tfa", "pass"]):
    totale = 0
    corretti = 0
    for nome_file in os.listdir(cartella):
        if nome_file.endswith('.json'):
            percorso_file = os.path.join(cartella, nome_file)
            with open(percorso_file, 'r', encoding='utf-8') as f:
                nomeapp = ""
                for app in apps:
                    if app in nome_file:
                        nomeapp = app
                        break
                if nomeapp=="":
                    continue
                try:
                    dati = json.load(f)
                except json.JSONDecodeError:
                    continue
                for dato in dati:
                        totale += 1
                        if dato['correct'] is True:
                            corretti += 1
            percentuale = (corretti / totale * 100) if totale > 0 else 0


            if "Humanoid" in cartella:
                nomeapp += "-humanoid"
            if "Replay" in cartella:
                nomeapp += "-replay"
            if "LLAMA" in cartella:
                nomeapp += "-llama"
            if "Scelta" in cartella:
                nomeapp += "-scelta"
            if "prelogin" in nome_file:
                nomeapp += "-prelogin"
            elif "postlogin" in nome_file:
                nomeapp += "-postlogin"
            print(f"Analisi file: {nome_file} in {cartella}")
            print(f"Percentuale correttezza per {nomeapp} in {cartella_input}: {percentuale:.2f}% ({corretti}/{totale})")

# Esempio di utilizzo:
cartelle = [r"00-Droidbot Base",r"01-Droidbot Replay Output",r"02-Droidbot + LLAMA",r"03-Droidbot + LLAMA + Scelta", r"05-Humanoid + Replay Output", r"06-Humanoid + LLAMA"]

for cartella_input in cartelle:
    print(f"Analisi file in {cartella_input}" )
    calcola_percentuale_corretto(os.path.join(r"C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result",cartella_input))
    #calcola_percentuale_corretto(os.path.join(r"D:\documenti\UNI\LLM\progetto\git\Project_LLM_A3\Result",cartella_input))
    print("\n" +"\n")
# Out:
# Analisi file in 00-Droidbot Base
# Analisi file: risultati_output-note.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\00-Droidbot Base
# Percentuale correttezza per note in 00-Droidbot Base: 0.00% (0/62)
# Analisi file: risultati_output-pass.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\00-Droidbot Base
# Percentuale correttezza per pass in 00-Droidbot Base: 0.00% (0/66)
# Analisi file: risultati_output-tfa-postlogin.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\00-Droidbot Base
# Percentuale correttezza per tfa-postlogin in 00-Droidbot Base: 0.00% (0/167)
#
#
#
# Analisi file in 01-Droidbot Replay Output
# Analisi file: risultati_output-tfa-postlogin-replay.json in D:\documenti\UNI\LLM\progetto\git\Project_LLM_A3\Result\01-Droidbot Replay Output
# Percentuale correttezza per tfa-replay-postlogin in 01-Droidbot Replay Output: 38.61% (39/101)
#
#
#
# Analisi file in 02-Droidbot + LLAMA
# Analisi file: risultati_output-note-llama.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\02-Droidbot + LLAMA
# Percentuale correttezza per note-llama in 02-Droidbot + LLAMA: 0.00% (0/31)
# Analisi file: risultati_output-pass.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\02-Droidbot + LLAMA
# Percentuale correttezza per pass-llama in 02-Droidbot + LLAMA: 0.00% (0/31)
# Analisi file: risultati_output-tfa-postlogin.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\02-Droidbot + LLAMA
# Percentuale correttezza per tfa-llama-postlogin in 02-Droidbot + LLAMA: 0.00% (0/50)
# Analisi file: risultati_output-tfa-prelogin.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\02-Droidbot + LLAMA
# Percentuale correttezza per tfa-llama-prelogin in 02-Droidbot + LLAMA: 0.00% (0/60)
#
#
#
# Analisi file in 03-Droidbot + LLAMA + Scelta
# Analisi file: risultati_output-note.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\03-Droidbot + LLAMA + Scelta
# Percentuale correttezza per note-llama-scelta in 03-Droidbot + LLAMA + Scelta: 0.00% (0/85)
# Analisi file: risultati_output-pass.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\03-Droidbot + LLAMA + Scelta
# Percentuale correttezza per pass-llama-scelta in 03-Droidbot + LLAMA + Scelta: 3.85% (7/182)
# Analisi file: risultati_output-tfa-postlogin.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\03-Droidbot + LLAMA + Scelta
# Percentuale correttezza per tfa-llama-scelta-postlogin in 03-Droidbot + LLAMA + Scelta: 2.55% (7/275)
#
#
#
# Analisi file in 04-Humanoid Base
# Analisi file: risultati_output-note.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\04-Humanoid Base
# Percentuale correttezza per note-humanoid in 04-Humanoid Base: 0.00% (0/172)
# Analisi file: risultati_output-pass.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\04-Humanoid Base
# Percentuale correttezza per pass-humanoid in 04-Humanoid Base: 0.00% (0/224)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 49
#      47 for cartella_input in cartelle:
#      48     print(f"Analisi file in {cartella_input}" )
# ---> 49     calcola_percentuale_corretto(os.path.join(r"C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result",cartella_input))
#      50     #calcola_percentuale_corretto(os.path.join(r"D:\documenti\UNI\LLM\progetto\git\Project_LLM_A3\Result",cartella_input))
#      51     print("\n" +"\n")
#
# Cell In[3], line 19, in calcola_percentuale_corretto(cartella)
#      17     for dato in dati:
#      18             totale += 1
# ---> 19             if dato['correct'] is True:
#      20                 corretti += 1
#      21 percentuale = (corretti / totale * 100) if totale > 0 else 0
#
# KeyError: 'correct'
