# %%
import os
import json



def calcola_percentuale_corretto(cartella):
    totale = 0
    corretti = 0
    for nome_file in os.listdir(cartella):
        if nome_file.endswith('.json'):
            percorso_file = os.path.join(cartella, nome_file)
            with open(percorso_file, 'r', encoding='utf-8') as f:
                try:
                    dati = json.load(f)
                except json.JSONDecodeError:
                    continue
                for dato in dati:
                        totale += 1
                        if dato['correct'] is True:
                            corretti += 1
            percentuale = (corretti / totale * 100) if totale > 0 else 0
            if "note" in nome_file:
                nomeapp = "note"
            elif "tfa" in nome_file:
                nomeapp = "tfa"
            else:
                nomeapp = "pass"

            if "Humanoid" in cartella:
                nomeapp += "-humanoid"
            if "Replay" in cartella:
                nomeapp += "-replay"
            if "LLAMA" in cartella:
                nomeapp += "-llama"
            if "Scelta" in cartella:
                nomeapp += "-scelta"
            if "prelogin" in nome_file:
                nomeapp += "-prelogin"
            elif "postlogin" in nome_file:
                nomeapp += "-postlogin"
            print(f"Analisi file: {nome_file} in {cartella}")
            print(f"Percentuale correttezza per {nomeapp} in {cartella_input}: {percentuale:.2f}% ({corretti}/{totale})")

# Esempio di utilizzo:
cartelle = [r"01-Droidbot Replay Output",r"02-Droidbot + LLAMA",r"03-Droidbot + LLAMA + Scelta", r"05-Humanoid + Replay Output", r"06-Humanoid + LLAMA"]

for cartella_input in cartelle:
    print(f"Analisi file in {cartella_input}" )
    #calcola_percentuale_corretto(os.path.join(r"C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result",cartella_input))
    calcola_percentuale_corretto(os.path.join(r"D:\documenti\UNI\LLM\progetto\git\Project_LLM_A3\Result",cartella_input))
    print("\n" +"\n")
# Out:
# Analisi file in 01-Droidbot Replay Output
# Analisi file: risultati_output-note-replay.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\01-Droidbot Replay Output
# Percentuale correttezza per note-replay in 01-Droidbot Replay Output: 0.00% (0/62)
# Analisi file: risultati_output-pass-replay.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\01-Droidbot Replay Output
# Percentuale correttezza per pass-replay in 01-Droidbot Replay Output: 0.00% (0/66)
# Analisi file: risultati_output-tfa-postlogin-replay.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\01-Droidbot Replay Output
# Percentuale correttezza per tfa-replay-postlogin in 01-Droidbot Replay Output: 23.35% (39/167)
#
#
#
# Analisi file in 02-Droidbot + LLAMA
# Analisi file: risultati_output-note-llama.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\02-Droidbot + LLAMA
# Percentuale correttezza per note-llama in 02-Droidbot + LLAMA: 0.00% (0/31)
# Analisi file: risultati_output-pass-llama.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\02-Droidbot + LLAMA
# Percentuale correttezza per pass-llama in 02-Droidbot + LLAMA: 0.00% (0/31)
# Analisi file: risultati_output-tfa-postlogin.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\02-Droidbot + LLAMA
# Percentuale correttezza per tfa-llama-postlogin in 02-Droidbot + LLAMA: 0.00% (0/50)
# Analisi file: risultati_output-tfa-prelogin.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\02-Droidbot + LLAMA
# Percentuale correttezza per tfa-llama-prelogin in 02-Droidbot + LLAMA: 0.00% (0/60)
#
#
#
# Analisi file in 03-Droidbot + LLAMA + Scelta
# Analisi file: risultati_output-note.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\03-Droidbot + LLAMA + Scelta
# Percentuale correttezza per note-llama-scelta in 03-Droidbot + LLAMA + Scelta: 0.00% (0/85)
# Analisi file: risultati_output-pass.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\03-Droidbot + LLAMA + Scelta
# Percentuale correttezza per pass-llama-scelta in 03-Droidbot + LLAMA + Scelta: 0.00% (0/182)
# Analisi file: risultati_output-tfa-postlogin.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\03-Droidbot + LLAMA + Scelta
# Percentuale correttezza per tfa-llama-scelta-postlogin in 03-Droidbot + LLAMA + Scelta: 0.00% (0/275)
#
#
#
# Analisi file in 05-Humanoid + Replay Output
# Analisi file: risultati-humanoid-replay-note.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\05-Humanoid + Replay Output
# Percentuale correttezza per note-humanoid-replay in 05-Humanoid + Replay Output: 0.00% (0/172)
# Analisi file: risultati-humanoid-replay-pass.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\05-Humanoid + Replay Output
# Percentuale correttezza per pass-humanoid-replay in 05-Humanoid + Replay Output: 0.00% (0/224)
# Analisi file: risultati-humanoid-replay-tfa-prelogin.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\05-Humanoid + Replay Output
# Percentuale correttezza per tfa-humanoid-replay-prelogin in 05-Humanoid + Replay Output: 0.00% (0/233)
#
#
#
# Analisi file in 06-Humanoid + LLAMA
# Analisi file: risultati_output-note.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\06-Humanoid + LLAMA
# Percentuale correttezza per note-humanoid-llama in 06-Humanoid + LLAMA: 0.00% (0/158)
# Analisi file: risultati_output-pass.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\06-Humanoid + LLAMA
# Percentuale correttezza per pass-humanoid-llama in 06-Humanoid + LLAMA: 0.00% (0/289)
# Analisi file: risultati_output-tfa-postlogin.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\06-Humanoid + LLAMA
# Percentuale correttezza per tfa-humanoid-llama-postlogin in 06-Humanoid + LLAMA: 8.52% (27/317)
# Analisi file: risultati_output-tfa-prelogin.json in C:\Users\juve2\Desktop\Projects\Project_LLM_A3\Result\06-Humanoid + LLAMA
# Percentuale correttezza per tfa-humanoid-llama-prelogin in 06-Humanoid + LLAMA: 8.58% (29/338)
